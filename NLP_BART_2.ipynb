# %%
# !pip -qq install transformers datasets rouge_score nltk
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.7 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
from datasets import load_dataset
from transformers import T5Tokenizer, T5ForConditionalGeneration, AdamW
from rouge_score import rouge_scorer
from torch.utils.data import DataLoader
from torch import nn
import torch
import re
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from torch.cuda.amp import autocast, GradScaler
from transformers import BartTokenizer, BartForConditionalGeneration

# Device setting
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Loading pre-trained BART model and tokenizer
bart_model_name = 'facebook/bart-large-cnn'
print(f"Loading BART model: {bart_model_name}")
tokenizer = BartTokenizer.from_pretrained(bart_model_name)
model = BartForConditionalGeneration.from_pretrained(bart_model_name)
model.to(device)

# Text Preprocessing
def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    return text

# Summarization function for BART
def summarize_text_bart(article):
    print("Summarizing article...")
    input_ids = tokenizer.encode(article, return_tensors="pt", max_length=1024, truncation=True).to(device)
    summary_ids = model.generate(input_ids, max_length=150, min_length=30, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# Evaluation using ROUGE and BLEU with Smoothing
def evaluate_model(dataset):
    print("Starting evaluation...")
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = {'rouge1': [], 'rouge2': [], 'rougeL': [], 'bleu': []}
    smooth = SmoothingFunction().method4  # Applying smoothing to BLEU

    for idx, item in enumerate(dataset):
        print(f"Evaluating item {idx + 1}/{len(dataset)}")
        article = preprocess_text(item['Annual Reports'])
        gold_summary = preprocess_text(item['Gold Summaries'])

        if article:
            generated_summary = summarize_text_bart(article)

            # ROUGE scores
            score = scorer.score(gold_summary, generated_summary)
            scores['rouge1'].append(score['rouge1'].fmeasure)
            scores['rouge2'].append(score['rouge2'].fmeasure)
            scores['rougeL'].append(score['rougeL'].fmeasure)

            # BLEU score with smoothing
            reference = gold_summary.split()  # Tokenizing gold summary
            candidate = generated_summary.split()  # Tokenizing generated summary
            bleu_score = sentence_bleu([reference], candidate, smoothing_function=smooth)
            scores['bleu'].append(bleu_score)

    avg_rouge1 = sum(scores['rouge1']) / len(scores['rouge1'])
    avg_rouge2 = sum(scores['rouge2']) / len(scores['rouge2'])
    avg_rougeL = sum(scores['rougeL']) / len(scores['rougeL'])
    avg_bleu = sum(scores['bleu']) / len(scores['bleu'])

    return avg_rouge1, avg_rouge2, avg_rougeL, avg_bleu

# Training model
def fine_tune_model(train_data, epochs=3, learning_rate=5e-5):
    print(f"Starting fine-tuning for {epochs} epochs with learning rate {learning_rate}...")
    model.train()
    optimizer = AdamW(model.parameters(), lr=learning_rate)
    loss_fn = nn.CrossEntropyLoss()

    dataloader = DataLoader(train_data, batch_size=8, shuffle=True)

    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")
        total_loss = 0
        for batch_idx, batch in enumerate(dataloader):
            optimizer.zero_grad()
            input_texts = batch['Annual Reports']
            target_summaries = batch['Gold Summaries']

            inputs = tokenizer(input_texts, return_tensors="pt", max_length=512, truncation=True, padding=True).input_ids.to(device)
            targets = tokenizer(target_summaries, return_tensors="pt", max_length=150, truncation=True, padding=True).input_ids.to(device)

            outputs = model(input_ids=inputs, labels=targets)
            loss = outputs.loss
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if (batch_idx + 1) % 100 == 0:
                print(f"Batch {batch_idx + 1}/{len(dataloader)} - Loss: {loss.item()}")

        print(f"Epoch {epoch+1}/{epochs} Average Loss: {total_loss / len(dataloader)}")

# Implementing Main function
def main():
    print("Loading datasets...")
    train_data = load_dataset("ragha92/FNS_Summarization", split="train")
    validation_data = load_dataset("ragha92/FNS_Summarization", split="validation")
    test_data = load_dataset("ragha92/FNS_Summarization", split="test")

    print("Fine-tuning model...")
    fine_tune_model(train_data, epochs=3)

    print("Evaluating on the validation set...")
    avg_rouge1, avg_rouge2, avg_rougeL, avg_bleu = evaluate_model(validation_data)
    print(f"Validation ROUGE-1: {avg_rouge1}, ROUGE-2: {avg_rouge2}, ROUGE-L: {avg_rougeL}, BLEU: {avg_bleu}")

    print("Evaluating on the test dataset...")
    avg_rouge1, avg_rouge2, avg_rougeL, avg_bleu = evaluate_model(test_data)
    print(f"Test Set ROUGE-1: {avg_rouge1}")
    print(f"Test Set ROUGE-2: {avg_rouge2}")
    print(f"Test Set ROUGE-L: {avg_rougeL}")
    print(f"Test Set BLEU: {avg_bleu}")

# Defining Main Function
if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Loading BART model: facebook/bart-large-cnn
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Loading datasets...
# README.md:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# train.csv:   0%|          | 0.00/544M [00:00<?, ?B/s]
# validation.csv:   0%|          | 0.00/68.6M [00:00<?, ?B/s]
# test.csv:   0%|          | 0.00/67.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2060 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/257 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/259 [00:00<?, ? examples/s]
# Fine-tuning model...
# Starting fine-tuning for 3 epochs with learning rate 5e-05...
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/3
# Batch 100/258 - Loss: 2.9208078384399414
# Batch 200/258 - Loss: 2.5019431114196777
# Epoch 1/3 Average Loss: 2.832784535810929
# Epoch 2/3
# Batch 100/258 - Loss: 1.8910436630249023
# Batch 200/258 - Loss: 2.6964032649993896
# Epoch 2/3 Average Loss: 2.2358598436496053
# Epoch 3/3
# Batch 100/258 - Loss: 2.02034068107605
# Batch 200/258 - Loss: 2.111929416656494
# Epoch 3/3 Average Loss: 1.8657451064087625
# Evaluating on the validation set...
# Starting evaluation...
# Evaluating item 1/257
# Summarizing article...
# Evaluating item 2/257
# Summarizing article...
# Evaluating item 3/257
# Summarizing article...
# Evaluating item 4/257
# Summarizing article...
# Evaluating item 5/257
# Summarizing article...
# Evaluating item 6/257
# Summarizing article...
# Evaluating item 7/257
# Summarizing article...
# Evaluating item 8/257
# Summarizing article...
# Evaluating item 9/257
# Summarizing article...
# Evaluating item 10/257
# Summarizing article...
# Evaluating item 11/257
# Summarizing article...
# Evaluating item 12/257
# Summarizing article...
# Evaluating item 13/257
# Summarizing article...
# Evaluating item 14/257
# Summarizing article...
# Evaluating item 15/257
# Summarizing article...
# Evaluating item 16/257
# Summarizing article...
# Evaluating item 17/257
# Summarizing article...
# Evaluating item 18/257
# Summarizing article...
# Evaluating item 19/257
# Summarizing article...
# Evaluating item 20/257
# Summarizing article...
# Evaluating item 21/257
# Summarizing article...
# Evaluating item 22/257
# Summarizing article...
# Evaluating item 23/257
# Summarizing article...
# Evaluating item 24/257
# Summarizing article...
# Evaluating item 25/257
# Summarizing article...
# Evaluating item 26/257
# Summarizing article...
# Evaluating item 27/257
# Summarizing article...
# Evaluating item 28/257
# Summarizing article...
# Evaluating item 29/257
# Summarizing article...
# Evaluating item 30/257
# Summarizing article...
# Evaluating item 31/257
# Summarizing article...
# Evaluating item 32/257
# Summarizing article...
# Evaluating item 33/257
# Summarizing article...
# Evaluating item 34/257
# Summarizing article...
# Evaluating item 35/257
# Summarizing article...
# Evaluating item 36/257
# Summarizing article...
# Evaluating item 37/257
# Summarizing article...
# Evaluating item 38/257
# Summarizing article...
# Evaluating item 39/257
# Summarizing article...
# Evaluating item 40/257
# Summarizing article...
# Evaluating item 41/257
# Summarizing article...
# Evaluating item 42/257
# Summarizing article...
# Evaluating item 43/257
# Summarizing article...
# Evaluating item 44/257
# Summarizing article...
# Evaluating item 45/257
# Summarizing article...
# Evaluating item 46/257
# Summarizing article...
# Evaluating item 47/257
# Summarizing article...
# Evaluating item 48/257
# Summarizing article...
# Evaluating item 49/257
# Summarizing article...
# Evaluating item 50/257
# Summarizing article...
# Evaluating item 51/257
# Summarizing article...
# Evaluating item 52/257
# Summarizing article...
# Evaluating item 53/257
# Summarizing article...
# Evaluating item 54/257
# Summarizing article...
# Evaluating item 55/257
# Summarizing article...
# Evaluating item 56/257
# Summarizing article...
# Evaluating item 57/257
# Summarizing article...
# Evaluating item 58/257
# Summarizing article...
# Evaluating item 59/257
# Summarizing article...
# Evaluating item 60/257
# Summarizing article...
# Evaluating item 61/257
# Summarizing article...
# Evaluating item 62/257
# Summarizing article...
# Evaluating item 63/257
# Summarizing article...
# Evaluating item 64/257
# Summarizing article...
# Evaluating item 65/257
# Summarizing article...
# Evaluating item 66/257
# Summarizing article...
# Evaluating item 67/257
# Summarizing article...
# Evaluating item 68/257
# Summarizing article...
# Evaluating item 69/257
# Summarizing article...
# Evaluating item 70/257
# Summarizing article...
# Evaluating item 71/257
# Summarizing article...
# Evaluating item 72/257
# Summarizing article...
# Evaluating item 73/257
# Summarizing article...
# Evaluating item 74/257
# Summarizing article...
# Evaluating item 75/257
# Summarizing article...
# Evaluating item 76/257
# Summarizing article...
# Evaluating item 77/257
# Summarizing article...
# Evaluating item 78/257
# Summarizing article...
# Evaluating item 79/257
# Summarizing article...
# Evaluating item 80/257
# Summarizing article...
# Evaluating item 81/257
# Summarizing article...
# Evaluating item 82/257
# Summarizing article...
# Evaluating item 83/257
# Summarizing article...
# Evaluating item 84/257
# Summarizing article...
# Evaluating item 85/257
# Summarizing article...
# Evaluating item 86/257
# Summarizing article...
# Evaluating item 87/257
# Summarizing article...
# Evaluating item 88/257
# Summarizing article...
# Evaluating item 89/257
# Summarizing article...
# Evaluating item 90/257
# Summarizing article...
# Evaluating item 91/257
# Summarizing article...
# Evaluating item 92/257
# Summarizing article...
# Evaluating item 93/257
# Summarizing article...
# Evaluating item 94/257
# Summarizing article...
# Evaluating item 95/257
# Summarizing article...
# Evaluating item 96/257
# Summarizing article...
# Evaluating item 97/257
# Summarizing article...
# Evaluating item 98/257
# Summarizing article...
# Evaluating item 99/257
# Summarizing article...
# Evaluating item 100/257
# Summarizing article...
# Evaluating item 101/257
# Summarizing article...
# Evaluating item 102/257
# Summarizing article...
# Evaluating item 103/257
# Summarizing article...
# Evaluating item 104/257
# Summarizing article...
# Evaluating item 105/257
# Summarizing article...
# Evaluating item 106/257
# Summarizing article...
# Evaluating item 107/257
# Summarizing article...
# Evaluating item 108/257
# Summarizing article...
# Evaluating item 109/257
# Summarizing article...
# Evaluating item 110/257
# Summarizing article...
# Evaluating item 111/257
# Summarizing article...
# Evaluating item 112/257
# Summarizing article...
# Evaluating item 113/257
# Summarizing article...
# Evaluating item 114/257
# Summarizing article...
# Evaluating item 115/257
# Summarizing article...
# Evaluating item 116/257
# Summarizing article...
# Evaluating item 117/257
# Summarizing article...
# Evaluating item 118/257
# Summarizing article...
# Evaluating item 119/257
# Summarizing article...
# Evaluating item 120/257
# Summarizing article...
# Evaluating item 121/257
# Summarizing article...
# Evaluating item 122/257
# Summarizing article...
# Evaluating item 123/257
# Summarizing article...
# Evaluating item 124/257
# Summarizing article...
# Evaluating item 125/257
# Summarizing article...
# Evaluating item 126/257
# Summarizing article...
# Evaluating item 127/257
# Summarizing article...
# Evaluating item 128/257
# Summarizing article...
# Evaluating item 129/257
# Summarizing article...
# Evaluating item 130/257
# Summarizing article...
# Evaluating item 131/257
# Summarizing article...
# Evaluating item 132/257
# Summarizing article...
# Evaluating item 133/257
# Summarizing article...
# Evaluating item 134/257
# Summarizing article...
# Evaluating item 135/257
# Summarizing article...
# Evaluating item 136/257
# Summarizing article...
# Evaluating item 137/257
# Summarizing article...
# Evaluating item 138/257
# Summarizing article...
# Evaluating item 139/257
# Summarizing article...
# Evaluating item 140/257
# Summarizing article...
# Evaluating item 141/257
# Summarizing article...
# Evaluating item 142/257
# Summarizing article...
# Evaluating item 143/257
# Summarizing article...
# Evaluating item 144/257
# Summarizing article...
# Evaluating item 145/257
# Summarizing article...
# Evaluating item 146/257
# Summarizing article...
# Evaluating item 147/257
# Summarizing article...
# Evaluating item 148/257
# Summarizing article...
# Evaluating item 149/257
# Summarizing article...
# Evaluating item 150/257
# Summarizing article...
# Evaluating item 151/257
# Summarizing article...
# Evaluating item 152/257
# Summarizing article...
# Evaluating item 153/257
# Summarizing article...
# Evaluating item 154/257
# Summarizing article...
# Evaluating item 155/257
# Summarizing article...
# Evaluating item 156/257
# Summarizing article...
# Evaluating item 157/257
# Summarizing article...
# Evaluating item 158/257
# Summarizing article...
# Evaluating item 159/257
# Summarizing article...
# Evaluating item 160/257
# Summarizing article...
# Evaluating item 161/257
# Summarizing article...
# Evaluating item 162/257
# Summarizing article...
# Evaluating item 163/257
# Summarizing article...
# Evaluating item 164/257
# Summarizing article...
# Evaluating item 165/257
# Summarizing article...
# Evaluating item 166/257
# Summarizing article...
# Evaluating item 167/257
# Summarizing article...
# Evaluating item 168/257
# Summarizing article...
# Evaluating item 169/257
# Summarizing article...
# Evaluating item 170/257
# Summarizing article...
# Evaluating item 171/257
# Summarizing article...
# Evaluating item 172/257
# Summarizing article...
# Evaluating item 173/257
# Summarizing article...
# Evaluating item 174/257
# Summarizing article...
# Evaluating item 175/257
# Summarizing article...
# Evaluating item 176/257
# Summarizing article...
# Evaluating item 177/257
# Summarizing article...
# Evaluating item 178/257
# Summarizing article...
# Evaluating item 179/257
# Summarizing article...
# Evaluating item 180/257
# Summarizing article...
# Evaluating item 181/257
# Summarizing article...
# Evaluating item 182/257
# Summarizing article...
# Evaluating item 183/257
# Summarizing article...
# Evaluating item 184/257
# Summarizing article...
# Evaluating item 185/257
# Summarizing article...
# Evaluating item 186/257
# Summarizing article...
# Evaluating item 187/257
# Summarizing article...
# Evaluating item 188/257
# Summarizing article...
# Evaluating item 189/257
# Summarizing article...
# Evaluating item 190/257
# Summarizing article...
# Evaluating item 191/257
# Summarizing article...
# Evaluating item 192/257
# Summarizing article...
# Evaluating item 193/257
# Summarizing article...
# Evaluating item 194/257
# Summarizing article...
# Evaluating item 195/257
# Summarizing article...
# Evaluating item 196/257
# Summarizing article...
# Evaluating item 197/257
# Summarizing article...
# Evaluating item 198/257
# Summarizing article...
# Evaluating item 199/257
# Summarizing article...
# Evaluating item 200/257
# Summarizing article...
# Evaluating item 201/257
# Summarizing article...
# Evaluating item 202/257
# Summarizing article...
# Evaluating item 203/257
# Summarizing article...
# Evaluating item 204/257
# Summarizing article...
# Evaluating item 205/257
# Summarizing article...
# Evaluating item 206/257
# Summarizing article...
# Evaluating item 207/257
# Summarizing article...
# Evaluating item 208/257
# Summarizing article...
# Evaluating item 209/257
# Summarizing article...
# Evaluating item 210/257
# Summarizing article...
# Evaluating item 211/257
# Summarizing article...
# Evaluating item 212/257
# Summarizing article...
# Evaluating item 213/257
# Summarizing article...
# Evaluating item 214/257
# Summarizing article...
# Evaluating item 215/257
# Summarizing article...
# Evaluating item 216/257
# Summarizing article...
# Evaluating item 217/257
# Summarizing article...
# Evaluating item 218/257
# Summarizing article...
# Evaluating item 219/257
# Summarizing article...
# Evaluating item 220/257
# Summarizing article...
# Evaluating item 221/257
# Summarizing article...
# Evaluating item 222/257
# Summarizing article...
# Evaluating item 223/257
# Summarizing article...
# Evaluating item 224/257
# Summarizing article...
# Evaluating item 225/257
# Summarizing article...
# Evaluating item 226/257
# Summarizing article...
# Evaluating item 227/257
# Summarizing article...
# Evaluating item 228/257
# Summarizing article...
# Evaluating item 229/257
# Summarizing article...
# Evaluating item 230/257
# Summarizing article...
# Evaluating item 231/257
# Summarizing article...
# Evaluating item 232/257
# Summarizing article...
# Evaluating item 233/257
# Summarizing article...
# Evaluating item 234/257
# Summarizing article...
# Evaluating item 235/257
# Summarizing article...
# Evaluating item 236/257
# Summarizing article...
# Evaluating item 237/257
# Summarizing article...
# Evaluating item 238/257
# Summarizing article...
# Evaluating item 239/257
# Summarizing article...
# Evaluating item 240/257
# Summarizing article...
# Evaluating item 241/257
# Summarizing article...
# Evaluating item 242/257
# Summarizing article...
# Evaluating item 243/257
# Summarizing article...
# Evaluating item 244/257
# Summarizing article...
# Evaluating item 245/257
# Summarizing article...
# Evaluating item 246/257
# Summarizing article...
# Evaluating item 247/257
# Summarizing article...
# Evaluating item 248/257
# Summarizing article...
# Evaluating item 249/257
# Summarizing article...
# Evaluating item 250/257
# Summarizing article...
# Evaluating item 251/257
# Summarizing article...
# Evaluating item 252/257
# Summarizing article...
# Evaluating item 253/257
# Summarizing article...
# Evaluating item 254/257
# Summarizing article...
# Evaluating item 255/257
# Summarizing article...
# Evaluating item 256/257
# Summarizing article...
# Evaluating item 257/257
# Summarizing article...
# Validation ROUGE-1: 0.1811547164995737, ROUGE-2: 0.09139012827999732, ROUGE-L: 0.12445815998281229, BLEU: 0.021452250481537878
# Evaluating on the test dataset...
# Starting evaluation...
# Evaluating item 1/259
# Summarizing article...
# Evaluating item 2/259
# Summarizing article...
# Evaluating item 3/259
# Summarizing article...
# Evaluating item 4/259
# Summarizing article...
# Evaluating item 5/259
# Summarizing article...
# Evaluating item 6/259
# Summarizing article...
# Evaluating item 7/259
# Summarizing article...
# Evaluating item 8/259
# Summarizing article...
# Evaluating item 9/259
# Summarizing article...
# Evaluating item 10/259
# Summarizing article...
# Evaluating item 11/259
# Summarizing article...
# Evaluating item 12/259
# Summarizing article...
# Evaluating item 13/259
# Summarizing article...
# Evaluating item 14/259
# Summarizing article...
# Evaluating item 15/259
# Summarizing article...
# Evaluating item 16/259
# Summarizing article...
# Evaluating item 17/259
# Summarizing article...
# Evaluating item 18/259
# Summarizing article...
# Evaluating item 19/259
# Summarizing article...
# Evaluating item 20/259
# Summarizing article...
# Evaluating item 21/259
# Summarizing article...
# Evaluating item 22/259
# Summarizing article...
# Evaluating item 23/259
# Summarizing article...
# Evaluating item 24/259
# Summarizing article...
# Evaluating item 25/259
# Summarizing article...
# Evaluating item 26/259
# Summarizing article...
# Evaluating item 27/259
# Summarizing article...
# Evaluating item 28/259
# Summarizing article...
# Evaluating item 29/259
# Summarizing article...
# Evaluating item 30/259
# Summarizing article...
# Evaluating item 31/259
# Summarizing article...
# Evaluating item 32/259
# Summarizing article...
# Evaluating item 33/259
# Summarizing article...
# Evaluating item 34/259
# Summarizing article...
# Evaluating item 35/259
# Summarizing article...
# Evaluating item 36/259
# Summarizing article...
# Evaluating item 37/259
# Summarizing article...
# Evaluating item 38/259
# Summarizing article...
# Evaluating item 39/259
# Summarizing article...
# Evaluating item 40/259
# Summarizing article...
# Evaluating item 41/259
# Summarizing article...
# Evaluating item 42/259
# Summarizing article...
# Evaluating item 43/259
# Summarizing article...
# Evaluating item 44/259
# Summarizing article...
# Evaluating item 45/259
# Summarizing article...
# Evaluating item 46/259
# Summarizing article...
# Evaluating item 47/259
# Summarizing article...
# Evaluating item 48/259
# Summarizing article...
# Evaluating item 49/259
# Summarizing article...
# Evaluating item 50/259
# Summarizing article...
# Evaluating item 51/259
# Summarizing article...
# Evaluating item 52/259
# Summarizing article...
# Evaluating item 53/259
# Summarizing article...
# Evaluating item 54/259
# Summarizing article...
# Evaluating item 55/259
# Summarizing article...
# Evaluating item 56/259
# Summarizing article...
# Evaluating item 57/259
# Summarizing article...
# Evaluating item 58/259
# Summarizing article...
# Evaluating item 59/259
# Summarizing article...
# Evaluating item 60/259
# Summarizing article...
# Evaluating item 61/259
# Summarizing article...
# Evaluating item 62/259
# Summarizing article...
# Evaluating item 63/259
# Summarizing article...
# Evaluating item 64/259
# Summarizing article...
# Evaluating item 65/259
# Summarizing article...
# Evaluating item 66/259
# Summarizing article...
# Evaluating item 67/259
# Summarizing article...
# Evaluating item 68/259
# Summarizing article...
# Evaluating item 69/259
# Summarizing article...
# Evaluating item 70/259
# Summarizing article...
# Evaluating item 71/259
# Summarizing article...
# Evaluating item 72/259
# Summarizing article...
# Evaluating item 73/259
# Summarizing article...
# Evaluating item 74/259
# Summarizing article...
# Evaluating item 75/259
# Summarizing article...
# Evaluating item 76/259
# Summarizing article...
# Evaluating item 77/259
# Summarizing article...
# Evaluating item 78/259
# Summarizing article...
# Evaluating item 79/259
# Summarizing article...
# Evaluating item 80/259
# Summarizing article...
# Evaluating item 81/259
# Summarizing article...
# Evaluating item 82/259
# Summarizing article...
# Evaluating item 83/259
# Summarizing article...
# Evaluating item 84/259
# Summarizing article...
# Evaluating item 85/259
# Summarizing article...
# Evaluating item 86/259
# Summarizing article...
# Evaluating item 87/259
# Summarizing article...
# Evaluating item 88/259
# Summarizing article...
# Evaluating item 89/259
# Summarizing article...
# Evaluating item 90/259
# Evaluating item 91/259
# Summarizing article...
# Evaluating item 92/259
# Summarizing article...
# Evaluating item 93/259
# Summarizing article...
# Evaluating item 94/259
# Summarizing article...
# Evaluating item 95/259
# Summarizing article...
# Evaluating item 96/259
# Summarizing article...
# Evaluating item 97/259
# Summarizing article...
# Evaluating item 98/259
# Summarizing article...
# Evaluating item 99/259
# Summarizing article...
# Evaluating item 100/259
# Summarizing article...
# Evaluating item 101/259
# Summarizing article...
# Evaluating item 102/259
# Summarizing article...
# Evaluating item 103/259
# Summarizing article...
# Evaluating item 104/259
# Summarizing article...
# Evaluating item 105/259
# Summarizing article...
# Evaluating item 106/259
# Summarizing article...
# Evaluating item 107/259
# Summarizing article...
# Evaluating item 108/259
# Summarizing article...
# Evaluating item 109/259
# Summarizing article...
# Evaluating item 110/259
# Summarizing article...
# Evaluating item 111/259
# Summarizing article...
# Evaluating item 112/259
# Summarizing article...
# Evaluating item 113/259
# Summarizing article...
# Evaluating item 114/259
# Summarizing article...
# Evaluating item 115/259
# Summarizing article...
# Evaluating item 116/259
# Summarizing article...
# Evaluating item 117/259
# Summarizing article...
# Evaluating item 118/259
# Summarizing article...
# Evaluating item 119/259
# Summarizing article...
# Evaluating item 120/259
# Summarizing article...
# Evaluating item 121/259
# Summarizing article...
# Evaluating item 122/259
# Summarizing article...
# Evaluating item 123/259
# Summarizing article...
# Evaluating item 124/259
# Summarizing article...
# Evaluating item 125/259
# Summarizing article...
# Evaluating item 126/259
# Summarizing article...
# Evaluating item 127/259
# Summarizing article...
# Evaluating item 128/259
# Summarizing article...
# Evaluating item 129/259
# Summarizing article...
# Evaluating item 130/259
# Summarizing article...
# Evaluating item 131/259
# Summarizing article...
# Evaluating item 132/259
# Summarizing article...
# Evaluating item 133/259
# Summarizing article...
# Evaluating item 134/259
# Summarizing article...
# Evaluating item 135/259
# Summarizing article...
# Evaluating item 136/259
# Summarizing article...
# Evaluating item 137/259
# Summarizing article...
# Evaluating item 138/259
# Summarizing article...
# Evaluating item 139/259
# Summarizing article...
# Evaluating item 140/259
# Summarizing article...
# Evaluating item 141/259
# Summarizing article...
# Evaluating item 142/259
# Summarizing article...
# Evaluating item 143/259
# Summarizing article...
# Evaluating item 144/259
# Summarizing article...
# Evaluating item 145/259
# Summarizing article...
# Evaluating item 146/259
# Summarizing article...
# Evaluating item 147/259
# Summarizing article...
# Evaluating item 148/259
# Summarizing article...
# Evaluating item 149/259
# Summarizing article...
# Evaluating item 150/259
# Summarizing article...
# Evaluating item 151/259
# Summarizing article...
# Evaluating item 152/259
# Summarizing article...
# Evaluating item 153/259
# Summarizing article...
# Evaluating item 154/259
# Summarizing article...
# Evaluating item 155/259
# Summarizing article...
# Evaluating item 156/259
# Summarizing article...
# Evaluating item 157/259
# Summarizing article...
# Evaluating item 158/259
# Summarizing article...
# Evaluating item 159/259
# Summarizing article...
# Evaluating item 160/259
# Summarizing article...
# Evaluating item 161/259
# Summarizing article...
# Evaluating item 162/259
# Summarizing article...
# Evaluating item 163/259
# Summarizing article...
# Evaluating item 164/259
# Summarizing article...
# Evaluating item 165/259
# Summarizing article...
# Evaluating item 166/259
# Summarizing article...
# Evaluating item 167/259
# Summarizing article...
# Evaluating item 168/259
# Summarizing article...
# Evaluating item 169/259
# Summarizing article...
# Evaluating item 170/259
# Summarizing article...
# Evaluating item 171/259
# Summarizing article...
# Evaluating item 172/259
# Summarizing article...
# Evaluating item 173/259
# Summarizing article...
# Evaluating item 174/259
# Summarizing article...
# Evaluating item 175/259
# Summarizing article...
# Evaluating item 176/259
# Summarizing article...
# Evaluating item 177/259
# Summarizing article...
# Evaluating item 178/259
# Summarizing article...
# Evaluating item 179/259
# Summarizing article...
# Evaluating item 180/259
# Summarizing article...
# Evaluating item 181/259
# Summarizing article...
# Evaluating item 182/259
# Summarizing article...
# Evaluating item 183/259
# Summarizing article...
# Evaluating item 184/259
# Summarizing article...
# Evaluating item 185/259
# Summarizing article...
# Evaluating item 186/259
# Summarizing article...
# Evaluating item 187/259
# Summarizing article...
# Evaluating item 188/259
# Summarizing article...
# Evaluating item 189/259
# Summarizing article...
# Evaluating item 190/259
# Summarizing article...
# Evaluating item 191/259
# Summarizing article...
# Evaluating item 192/259
# Summarizing article...
# Evaluating item 193/259
# Summarizing article...
# Evaluating item 194/259
# Summarizing article...
# Evaluating item 195/259
# Summarizing article...
# Evaluating item 196/259
# Summarizing article...
# Evaluating item 197/259
# Summarizing article...
# Evaluating item 198/259
# Summarizing article...
# Evaluating item 199/259
# Summarizing article...
# Evaluating item 200/259
# Summarizing article...
# Evaluating item 201/259
# Summarizing article...
# Evaluating item 202/259
# Summarizing article...
# Evaluating item 203/259
# Summarizing article...
# Evaluating item 204/259
# Summarizing article...
# Evaluating item 205/259
# Summarizing article...
# Evaluating item 206/259
# Summarizing article...
# Evaluating item 207/259
# Summarizing article...
# Evaluating item 208/259
# Summarizing article...
# Evaluating item 209/259
# Summarizing article...
# Evaluating item 210/259
# Summarizing article...
# Evaluating item 211/259
# Summarizing article...
# Evaluating item 212/259
# Summarizing article...
# Evaluating item 213/259
# Summarizing article...
# Evaluating item 214/259
# Summarizing article...
# Evaluating item 215/259
# Summarizing article...
# Evaluating item 216/259
# Summarizing article...
# Evaluating item 217/259
# Summarizing article...
# Evaluating item 218/259
# Summarizing article...
# Evaluating item 219/259
# Summarizing article...
# Evaluating item 220/259
# Summarizing article...
# Evaluating item 221/259
# Summarizing article...
# Evaluating item 222/259
# Summarizing article...
# Evaluating item 223/259
# Summarizing article...
# Evaluating item 224/259
# Summarizing article...
# Evaluating item 225/259
# Summarizing article...
# Evaluating item 226/259
# Summarizing article...
# Evaluating item 227/259
# Summarizing article...
# Evaluating item 228/259
# Summarizing article...
# Evaluating item 229/259
# Summarizing article...
# Evaluating item 230/259
# Summarizing article...
# Evaluating item 231/259
# Summarizing article...
# Evaluating item 232/259
# Summarizing article...
# Evaluating item 233/259
# Summarizing article...
# Evaluating item 234/259
# Summarizing article...
# Evaluating item 235/259
# Summarizing article...
# Evaluating item 236/259
# Summarizing article...
# Evaluating item 237/259
# Summarizing article...
# Evaluating item 238/259
# Summarizing article...
# Evaluating item 239/259
# Summarizing article...
# Evaluating item 240/259
# Summarizing article...
# Evaluating item 241/259
# Summarizing article...
# Evaluating item 242/259
# Summarizing article...
# Evaluating item 243/259
# Summarizing article...
# Evaluating item 244/259
# Summarizing article...
# Evaluating item 245/259
# Evaluating item 246/259
# Summarizing article...
# Evaluating item 247/259
# Summarizing article...
# Evaluating item 248/259
# Summarizing article...
# Evaluating item 249/259
# Summarizing article...
# Evaluating item 250/259
# Summarizing article...
# Evaluating item 251/259
# Summarizing article...
# Evaluating item 252/259
# Summarizing article...
# Evaluating item 253/259
# Summarizing article...
# Evaluating item 254/259
# Summarizing article...
# Evaluating item 255/259
# Summarizing article...
# Evaluating item 256/259
# Summarizing article...
# Evaluating item 257/259
# Summarizing article...
# Evaluating item 258/259
# Summarizing article...
# Evaluating item 259/259
# Summarizing article...
# Test Set ROUGE-1: 0.17156404729692104
# Test Set ROUGE-2: 0.08651286701855243
# Test Set ROUGE-L: 0.11829339389834463
# Test Set BLEU: 0.019866959666862777

# %%
# !pip install torch
